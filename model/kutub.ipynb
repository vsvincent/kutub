# %%
import argparse
import os
import shutil
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema.document import Document
#from get_embedding_function import get_embedding_function
from langchain.vectorstores.chroma import Chroma
import pytesseract
from PIL import Image


CHROMA_PATH = "chroma"
DATA_PATH = "data"


def main():

    parser = argparse.ArgumentParser()
    parser.add_argument("--reset", action="store_true", help="Reset the database.")
    args = parser.parse_args()
    if args.reset:
        confirmationParser = argparse.ArgumentParser()
        print("Resetting vector store. This will delete all existing data.")
        confirmationParser.add_argument("--confirm", action="store_true", help="Confirm the reset.")
        if args.confirm:
            print("Reset confirmed.")
            clear_database()

    documents = load_documents()
    print(documents)
    chunks = split_documents(documents)
    print("sample chunks")
    print("0", chunks[0])
    print("1", chunks[1])
    print("2", chunks[2])
    print("3", chunks[3])
    print("4", chunks[4])
    print("5", chunks[5])
    print("6", chunks[6])
    print("7", chunks[7])
    print("8", chunks[8])
    print("15", chunks[100])
    #add_to_chroma(chunks)

def extract_text_from_image(image_path, language='eng'):
        img = Image.open(image_path)
        
        text = pytesseract.image_to_string(img, lang=language)
        
        return text

def load_documents():
    document_loader = PyPDFDirectoryLoader(DATA_PATH)
    return document_loader.load()


def split_documents(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=800,
        chunk_overlap=80,
        length_function=len,
        is_separator_regex=False,
    )
    return text_splitter.split_documents(documents)

def calculate_chunk_ids(chunks):
    # Page Source : Page Number : Chunk Index

    last_page_id = None
    current_chunk_index = 0

    for chunk in chunks:
        source = chunk.metadata.get("source")
        page = chunk.metadata.get("page")
        current_page_id = f"{source}:{page}"

        if current_page_id == last_page_id:
            current_chunk_index += 1
        else:
            current_chunk_index = 0

        chunk_id = f"{current_page_id}:{current_chunk_index}"
        last_page_id = current_page_id

        chunk.metadata["id"] = chunk_id

    return chunks

if __name__ == "__main__":
    main()
# Out:
# [Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 0}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 1}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 2}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 3}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 4}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 5}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 6}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 7}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 8}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 9}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 10}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 11}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 12}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 13}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 14}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 15}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 16}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 17}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 18}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 19}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 20}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 21}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 22}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 23}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 24}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 25}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 26}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 27}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 28}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 29}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 30}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 31}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 32}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 33}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 34}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 35}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 36}, page_content=''), Document(metadata={'source': 'data\\tafsir\\tafsir_ibn_kathir_vol_1.pdf', 'page': 37}, page_content=''), Document(metadata={ ...
# chunks
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 122
#     118         shutil.rmtree(CHROMA_PATH)
#     121 if __name__ == "__main__":
# --> 122     main()
#
# Cell In[1], line 30, in main()
#      28 chunks = split_documents(documents)
#      29 print("chunks")
# ---> 30 print("0", chunks[0])
#      31 print("1", chunks[1])
#      32 print("2", chunks[2])
#
# IndexError: list index out of range
